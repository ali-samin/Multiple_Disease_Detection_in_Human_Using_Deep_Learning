# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout
from sklearn.metrics import accuracy_score

# %%
import ipywidgets as widgets
import io
from PIL import Image
import tqdm
from sklearn.model_selection import train_test_split
import cv2
from sklearn.utils import shuffle
import tensorflow as tf

# %%
import os

# %%
X_train = []
Y_train = []
image_size = 150
labels = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
for i in labels:
    folderPath = os.path.join('./Training',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('./Testing',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
X_train,Y_train = shuffle(X_train,Y_train,random_state=101)
X_train.shape
# Out:
# (2947, 150, 150, 3)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,Y_train,test_size=0.1,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train=y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test=y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation = 'relu',input_shape=(150,150,3)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512,activation = 'relu'))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(4,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 64)      18496
#
#  max_pooling2d (MaxPooling2D  (None, 73, 73, 64)       0
#  )
#
#  dropout (Dropout)           (None, 73, 73, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 69, 69, 64)        36928
#
#  dropout_1 (Dropout)         (None, 69, 69, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 34, 34, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 34, 34, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 30, 30, 128)       147584
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_3 (Dropout)         (None, 14, 14, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       147584
#
#  conv2d_8 (Conv2D)           (None, 10, 10, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 5, 5, 256)         0
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense (Dense)               (None, 512)               3277312
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 4,447,044
# Trainable params: 4,447,044
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=20,validation_split=0.1)
# Out:
# Epoch 1/20
# 75/75 [==============================] - 38s 327ms/step - loss: 2.1124 - accuracy: 0.3018 - val_loss: 1.3669 - val_accuracy: 0.3045
# Epoch 2/20
# 75/75 [==============================] - 25s 334ms/step - loss: 1.3097 - accuracy: 0.3512 - val_loss: 1.1959 - val_accuracy: 0.5188
# Epoch 3/20
# 75/75 [==============================] - 26s 345ms/step - loss: 1.1431 - accuracy: 0.5050 - val_loss: 1.1263 - val_accuracy: 0.4850
# Epoch 4/20
# 75/75 [==============================] - 27s 364ms/step - loss: 1.0075 - accuracy: 0.5666 - val_loss: 0.9964 - val_accuracy: 0.5677
# Epoch 5/20
# 75/75 [==============================] - 23s 304ms/step - loss: 0.8856 - accuracy: 0.6081 - val_loss: 0.9007 - val_accuracy: 0.6541
# Epoch 6/20
# 75/75 [==============================] - 22s 296ms/step - loss: 0.8267 - accuracy: 0.6538 - val_loss: 0.8663 - val_accuracy: 0.6090
# Epoch 7/20
# 75/75 [==============================] - 20s 269ms/step - loss: 0.7637 - accuracy: 0.6873 - val_loss: 0.7942 - val_accuracy: 0.6767
# Epoch 8/20
# 75/75 [==============================] - 19s 252ms/step - loss: 0.6574 - accuracy: 0.7339 - val_loss: 0.6636 - val_accuracy: 0.7256
# Epoch 9/20
# 75/75 [==============================] - 19s 255ms/step - loss: 0.6161 - accuracy: 0.7414 - val_loss: 0.6140 - val_accuracy: 0.7556
# Epoch 10/20
# 75/75 [==============================] - 22s 292ms/step - loss: 0.5271 - accuracy: 0.7946 - val_loss: 0.5266 - val_accuracy: 0.7782
# Epoch 11/20
# 75/75 [==============================] - 21s 280ms/step - loss: 0.4442 - accuracy: 0.8340 - val_loss: 0.5653 - val_accuracy: 0.7820
# Epoch 12/20
# 75/75 [==============================] - 20s 263ms/step - loss: 0.3792 - accuracy: 0.8625 - val_loss: 0.5233 - val_accuracy: 0.8045
# Epoch 13/20
# 75/75 [==============================] - 20s 273ms/step - loss: 0.3383 - accuracy: 0.8709 - val_loss: 0.5147 - val_accuracy: 0.7707
# Epoch 14/20
# 75/75 [==============================] - 20s 263ms/step - loss: 0.2894 - accuracy: 0.8919 - val_loss: 0.4057 - val_accuracy: 0.8647
# Epoch 15/20
# 75/75 [==============================] - 19s 260ms/step - loss: 0.2701 - accuracy: 0.9019 - val_loss: 0.4419 - val_accuracy: 0.8308
# Epoch 16/20
# 75/75 [==============================] - 19s 259ms/step - loss: 0.2324 - accuracy: 0.9162 - val_loss: 0.4743 - val_accuracy: 0.8346
# Epoch 17/20
# 75/75 [==============================] - 19s 256ms/step - loss: 0.2193 - accuracy: 0.9267 - val_loss: 0.5587 - val_accuracy: 0.7406
# Epoch 18/20
# 75/75 [==============================] - 19s 260ms/step - loss: 0.1874 - accuracy: 0.9300 - val_loss: 0.3612 - val_accuracy: 0.8722
# Epoch 19/20
# 75/75 [==============================] - 20s 270ms/step - loss: 0.2036 - accuracy: 0.9288 - val_loss: 0.4044 - val_accuracy: 0.8684
# Epoch 20/20
# 75/75 [==============================] - 20s 264ms/step - loss: 0.1843 - accuracy: 0.9346 - val_loss: 0.4359 - val_accuracy: 0.8534

# %%
model.save('braintumor.h5')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(len(acc))
fig = plt.figure(figsize=(14,7))
plt.plot(epochs,acc,'r',label='Training Accuracy')
plt.plot(epochs,val_acc,'b',label='Validation Accuracy')
plt.legend(loc="upper left")
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))
fig = plt.figure(figsize=(14,7))
plt.plot(epochs,loss,'r',label='Training loss')
plt.plot(epochs,val_loss,'b',label='Validation loss')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ## Pridiction

# %%
img = cv2.imread('./image(28).JPG')
img = cv2.resize(img,(150,150))
img_array = np.array(img)
img_array.shape
# Out:
# (150, 150, 3)

# %%
img_array = img_array.reshape(1,150,150,3)
img_array.shape
# Out:
# (1, 150, 150, 3)

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img('./image(28).JPG')
plt.imshow(img,interpolation='nearest')
plt.show()

# %%
a = model.predict(img_array)
indices = a.argmax()
indices
# Out:
# 1/1 [==============================] - 0s 47ms/step
# 3

# %% [markdown]
# 0 = glioma_tumor
# 1 = meningioma_tumor
# 2 = no tumor
# 3 = pituitary_tumor

# %%
predicted_class = labels[indices]
print(predicted_class)
# Out:
# pituitary_tumor

# %%
model.save('braintumor_model.h5')

# %%
from keras.models import load_model

loaded_model = load_model('braintumor_model.h5')

# %%
new_img = cv2.imread('./image(91).JPG')
new_img = cv2.resize(new_img, (150, 150))
new_img_array = np.array(new_img)
new_img_array = new_img_array.reshape(1, 150, 150, 3)

prediction = loaded_model.predict(new_img_array)
predicted_class_index = np.argmax(prediction)
predicted_class = labels[predicted_class_index]

print("Predicted Class:", predicted_class)
# Out:
# 1/1 [==============================] - 0s 264ms/step
# Predicted Class: meningioma_tumor

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'model' is your trained model
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Creating the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 10/10 [==============================] - 1s 160ms/step
